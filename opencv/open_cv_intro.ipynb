# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

cv2_path = os.path.join(cv2.__path__, 'data')

# %%
img_path =
# Out:
# 4.11.0
# ['c:\\Users\\usuario\\anaconda3\\envs\\cursoMLconda\\Lib\\site-packages\\cv2']
